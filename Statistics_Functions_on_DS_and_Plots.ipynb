# %% [markdown]
# <a href="https://colab.research.google.com/github/AamirAli310/Python-Basics/blob/main/Statistics_Functions_on_DS_and_Plots.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Assignment Task 3: [50 Marks] – Report Format (Solution, Output & Explanation)
# Data Analysis and Visualization
#
# Q-8 and 9 solution

# %%
from google.colab import files
import pandas as pd
import numpy as np

salesDS = files.upload()
salesDS = pd.read_csv("Fortune 500 Companies.csv")
salesDS.head(6)
# Out:
#      <input type="file" id="files-b748e877-951c-4845-8e52-0b3a505a820f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b748e877-951c-4845-8e52-0b3a505a820f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
salesDS['revenue_mil'].mean()
salesDS.isnull().sum()
# Out:
# name                         0
# rank                         0
# year                         0
# industry                     0
# sector                       0
# headquarters_state           0
# headquarters_city            0
# market_value_mil           253
# revenue_mil                  0
# profit_mil                   3
# asset_mil                    0
# employees                    0
# founder_is_ceo               0
# female_ceo                   0
# newcomer_to_fortune_500      0
# dtype: int64

# %% [markdown]
# salesDS.info()
#
# Observations:
# 1 - Int base columns
# 2 - Float base data
# 3 - There are some null values
# 4 - Use number columns only for analysis

# %%
salesDS.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4500 entries, 0 to 4499
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   name                     4500 non-null   object
#  1   rank                     4500 non-null   int64
#  2   year                     4500 non-null   int64
#  3   industry                 4500 non-null   object
#  4   sector                   4500 non-null   object
#  5   headquarters_state       4500 non-null   object
#  6   headquarters_city        4500 non-null   object
#  7   market_value_mil         4247 non-null   float64
#  8   revenue_mil              4500 non-null   int64
#  9   profit_mil               4497 non-null   float64
#  10  asset_mil                4500 non-null   int64
#  11  employees                4500 non-null   float64
#  12  founder_is_ceo           4500 non-null   object
#  13  female_ceo               4500 non-null   object
# ...

# %% [markdown]
# Goind to remove null value base records to have better annalysis

# %%
nonnullSDS = salesDS.dropna(subset=['market_value_mil','profit_mil'])
nonnullSDS.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4244 entries, 0 to 4499
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   name                     4244 non-null   object
#  1   rank                     4244 non-null   int64
#  2   year                     4244 non-null   int64
#  3   industry                 4244 non-null   object
#  4   sector                   4244 non-null   object
#  5   headquarters_state       4244 non-null   object
#  6   headquarters_city        4244 non-null   object
#  7   market_value_mil         4244 non-null   float64
#  8   revenue_mil              4244 non-null   int64
#  9   profit_mil               4244 non-null   float64
#  10  asset_mil                4244 non-null   int64
#  11  employees                4244 non-null   float64
#  12  founder_is_ceo           4244 non-null   object
#  13  female_ceo               4244 non-null   object
# ...

# %%
nonnullSDS.isnull().sum()
# Out:
# name                       0
# rank                       0
# year                       0
# industry                   0
# sector                     0
# headquarters_state         0
# headquarters_city          0
# market_value_mil           0
# revenue_mil                0
# profit_mil                 0
# asset_mil                  0
# employees                  0
# founder_is_ceo             0
# female_ceo                 0
# newcomer_to_fortune_500    0
# dtype: int64

# %%
nonnullSDS.describe()
# Out:
#               rank         year  market_value_mil    revenue_mil  \
# count  4244.000000  4244.000000      4.244000e+03    4244.000000
# mean    251.111451  2019.016023      5.212963e+04   28161.379359
# std     144.429573     2.581544      1.348066e+05   47279.430254
# min       1.000000  2015.000000      1.000000e+01    5130.000000
# 25%     129.750000  2017.000000      7.524500e+03    8157.250000
# 50%     250.000000  2019.000000      1.831850e+04   12841.000000
# 75%     376.000000  2021.000000      4.681150e+04   24025.500000
# max     500.000000  2023.000000      2.849538e+06  611289.000000
#
#          profit_mil     asset_mil     employees
# count   4244.000000  4.244000e+03  4.244000e+03
# mean    2733.227144  9.001760e+04  5.905571e+04
# std     5894.376176  3.119129e+05  1.312129e+05
# min    -5403.000000  3.050000e+02  5.200000e+01
# 25%      431.000000  9.440500e+03  1.260000e+04
# 50%     1049.500000  2.139900e+04  2.637600e+04
# ...

# %% [markdown]
# Finding mean on revenue_mil

# %%
nonnullSDS['revenue_mil'].mean()
# Out:
# 28161.379359095194

# %% [markdown]
# Group dataset on which we want to perform observation

# %%
mySDS = nonnullSDS[['rank','year','revenue_mil','asset_mil']]
print("Mean:",mySDS['revenue_mil'].mean())
print("Median:",mySDS['revenue_mil'].median())
print("Std:",mySDS['revenue_mil'].std())
print("Variance:",mySDS['revenue_mil'].var())
print("Min:",mySDS['revenue_mil'].min())
print("Max:",mySDS['revenue_mil'].max())
print("Count:",mySDS['revenue_mil'].count())
Q1 = mySDS['revenue_mil'].quantile(0.25);
print("Quartile Q1:", Q1)
Q2 = mySDS['revenue_mil'].quantile(0.50)
print("Quartile Q2:",Q2)
Q3 = mySDS['revenue_mil'].quantile(0.75)
print("Quartile Q3:",Q3)
print("Finding Inter Quantile Range");
print("IQR: Q3 - Q1")
print("IQR=",Q3-Q1)
# Out:
# Mean: 28161.379359095194
# Median: 12841.0
# Std: 47279.430254324296
# Variance: 2235344525.1735153
# Min: 5130
# Max: 611289
# Count: 4244
# Quartile Q1: 8157.25
# Quartile Q2: 12841.0
# Quartile Q3: 24025.5
# Finding Inter Quantile Range
# IQR: Q3 - Q1
# IQR= 15868.25

# %% [markdown]
# Drawing Bell shape for the Data analysis to verify either it's normilized or Left or Right SKEWED

# %%
#mySDS['revenue_mil'].plot(kind='kde', ylabel="Volume")

#Ploting using seaborn library
import seaborn as sns
sns.distplot(mySDS['revenue_mil'], bins=15, hist_kws={'alpha': 0.4, 'color':'green'}, color="red")
#sns.histplot(mySDS['revenue_mil'], color="orange", binwidth=4)
# Out:
# <ipython-input-47-45e87777f33f>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(mySDS['revenue_mil'], bins=15, hist_kws={'alpha': 0.4, 'color':'green'}, color="red")
# <Axes: xlabel='revenue_mil', ylabel='Density'>
